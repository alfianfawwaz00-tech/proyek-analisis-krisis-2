# %% [markdown]
# <a href="https://colab.research.google.com/github/alfianfawwaz00-tech/proyek-analisis-krisis-2/blob/main/Mentahan10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/alfianfawwaz00-tech/proyek-analisis-krisis-2.git
# %cd proyek-analisis-krisis-2
# !pip install -r requirements.txt
# !python run_pipeline.py
# Out:
# Cloning into 'proyek-analisis-krisis-2'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 53 (delta 16), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (53/53), 29.63 KiB | 4.94 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/proyek-analisis-krisis-2
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.32.4)
# Requirement already satisfied: beautifulsoup4>=4.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.13.5)
# Requirement already satisfied: lxml>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (6.1.1)
# Collecting Sastrawi>=1.0.1 (from -r requirements.txt (line 6))
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Requirement already satisfied: yfinance>=0.2.40 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.2.66)
# Requirement already satisfied: openpyxl>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.1.5)
# Requirement already satisfied: scipy>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 1)) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 3)) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 3)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 3)) (2026.6.17)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.12.0->-r requirements.txt (line 4)) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.12.0->-r requirements.txt (line 4)) (4.16.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.40->-r requirements.txt (line 7)) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.40->-r requirements.txt (line 7)) (4.10.0)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.40->-r requirements.txt (line 7)) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.40->-r requirements.txt (line 7)) (4.2.2)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.40->-r requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.40->-r requirements.txt (line 7)) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.40->-r requirements.txt (line 7)) (15.0.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.2->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance>=0.2.40->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance>=0.2.40->-r requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance>=0.2.40->-r requirements.txt (line 7)) (3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance>=0.2.40->-r requirements.txt (line 7)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance>=0.2.40->-r requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.7->yfinance>=0.2.40->-r requirements.txt (line 7)) (0.1.2)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
#
# $ /usr/bin/python3 scraper_cnbc.py --per-periode 60
# [cnbc] 2022_RusiaUkraina: 60 berita -> cnbc_2022_RusiaUkraina.csv
# [cnbc] 2023_2024_TimurTengah: 60 berita -> cnbc_2023_2024_TimurTengah.csv
# [cnbc] 2025_PerangTarif: 60 berita -> cnbc_2025_PerangTarif.csv
# [cnbc] total: 180 berita
#
# $ /usr/bin/python3 scraper_investing.py --per-periode 60
# [investing] 2022_RusiaUkraina: 60 berita -> investing_2022_RusiaUkraina.csv
# [investing] 2023_2024_TimurTengah: 60 berita -> investing_2023_2024_TimurTengah.csv
# [investing] 2025_PerangTarif: 60 berita -> investing_2025_PerangTarif.csv
# [investing] total: 180 berita
#
# $ /usr/bin/python3 load_to_sql.py
# [stock] mengunduh harga dari Yahoo Finance ...
# [fetch] ADRO.JK  2022-02-01 .. 2022-12-31  (P1_2022_RusiaUkraina)
# [fetch] ENRG.JK  2022-02-01 .. 2022-12-31  (P1_2022_RusiaUkraina)
# [fetch] ITMG.JK  2022-02-01 .. 2022-12-31  (P1_2022_RusiaUkraina)
# [fetch] BBCA.JK  2022-02-01 .. 2022-12-31  (P1_2022_RusiaUkraina)
# [fetch] ADRO.JK  2023-10-01 .. 2024-06-30  (P2_2023_2024_TimurTengah)
# [fetch] ENRG.JK  2023-10-01 .. 2024-06-30  (P2_2023_2024_TimurTengah)
# [fetch] ITMG.JK  2023-10-01 .. 2024-06-30  (P2_2023_2024_TimurTengah)
# [fetch] BBCA.JK  2023-10-01 .. 2024-06-30  (P2_2023_2024_TimurTengah)
# [fetch] ADRO.JK  2025-01-01 .. 2025-12-31  (P3_2025_PerangTarif)
# [fetch] ENRG.JK  2025-01-01 .. 2025-12-31  (P3_2025_PerangTarif)
# [fetch] ITMG.JK  2025-01-01 .. 2025-12-31  (P3_2025_PerangTarif)
# [fetch] BBCA.JK  2025-01-01 .. 2025-12-31  (P3_2025_PerangTarif)
# [db] 360 berita & 2536 baris harga saham dimuat.
# [db] file: /content/proyek-analisis-krisis-2/database.db
#
# $ /usr/bin/python3 join_export.py
# [export] /content/proyek-analisis-krisis-2/data/output/hasil_gabungan.xlsx
# [export] 22 sheet ditulis (termasuk ringkasan).
#
# === Ringkasan Korelasi ===
#                  periode  ticker        mode  n_obs  pearson_r  pearson_p  spearman_r  spearman_p  mean_skor_net  mean_pct_change
#     P1_2022_RusiaUkraina ADRO.JK same_day_H0     73    -0.1486     0.2096     -0.1182      0.3194        -0.0092          -0.2579
#     P1_2022_RusiaUkraina ADRO.JK     lag_H+1     67    -0.1964     0.1111     -0.2031      0.0993        -0.0092           0.5916
#     P1_2022_RusiaUkraina ENRG.JK same_day_H0     73     0.1064     0.3703      0.1013      0.3937        -0.0092          -0.0639
#     P1_2022_RusiaUkraina ENRG.JK     lag_H+1     67    -0.1603     0.1951     -0.1338      0.2803        -0.0092           1.5767
#     P1_2022_RusiaUkraina ITMG.JK same_day_H0     73    -0.0986     0.4065     -0.0353      0.7670        -0.0092           0.1289
#     P1_2022_RusiaUkraina ITMG.JK     lag_H+1     67    -0.1050     0.3980     -0.1486      0.2301        -0.0092           0.5372
#     P1_2022_RusiaUkraina BBCA.JK same_day_H0     73    -0.0281     0.8137     -0.0808      0.4969        -0.0092          -0.1435
#     P1_2022_RusiaUkraina BBCA.JK     lag_H+1     67    -0.1264     0.3081     -0.0835      0.5020        -0.0092          -0.1068
# P2_2023_2024_TimurTengah ADRO.JK same_day_H0     69    -0.0902     0.4609     -0.1244      0.3086        -0.1651           0.0505
# P2_2023_2024_TimurTengah ADRO.JK     lag_H+1     63     0.0676     0.5987      0.0739      0.5648        -0.1651           0.0283
# P2_2023_2024_TimurTengah ENRG.JK same_day_H0     69    -0.0242     0.8437     -0.0142      0.9075        -0.1651          -0.0644
# P2_2023_2024_TimurTengah ENRG.JK     lag_H+1     63    -0.2056     0.1061     -0.2270      0.0736        -0.1651          -0.3608
# P2_2023_2024_TimurTengah ITMG.JK same_day_H0     69    -0.1771     0.1454     -0.2265      0.0613        -0.1651          -0.0907
# P2_2023_2024_TimurTengah ITMG.JK     lag_H+1     63     0.2126     0.0944      0.1363      0.2867        -0.1651           0.0659
# P2_2023_2024_TimurTengah BBCA.JK same_day_H0     69    -0.2535     0.0356     -0.2130      0.0789        -0.1651           0.1244
# P2_2023_2024_TimurTengah BBCA.JK     lag_H+1     63    -0.1214     0.3433     -0.1311      0.3059        -0.1651           0.2049
#      P3_2025_PerangTarif ADRO.JK same_day_H0     67     0.1180     0.3418      0.1653      0.1814        -0.1776          -0.2555
#      P3_2025_PerangTarif ADRO.JK     lag_H+1     76    -0.0079     0.9463     -0.0904      0.4373        -0.1776          -0.2687
#      P3_2025_PerangTarif ENRG.JK same_day_H0     67    -0.0616     0.6203     -0.0401      0.7475        -0.1776           1.5671
#      P3_2025_PerangTarif ENRG.JK     lag_H+1     76     0.0560     0.6308      0.1233      0.2887        -0.1776           1.5454
#      P3_2025_PerangTarif ITMG.JK same_day_H0     67    -0.0603     0.6281     -0.0133      0.9151        -0.1776          -0.0165
#      P3_2025_PerangTarif ITMG.JK     lag_H+1     76    -0.0241     0.8364      0.0982      0.3987        -0.1776          -0.3093
#      P3_2025_PerangTarif BBCA.JK same_day_H0     67     0.2692     0.0276      0.3052      0.0120        -0.1776           0.0753
#      P3_2025_PerangTarif BBCA.JK     lag_H+1     76     0.0582     0.6172     -0.0112      0.9233        -0.1776          -0.4045
#
# Selesai. Cek:
#   - /content/proyek-analisis-krisis-2/database.db
#   - /content/proyek-analisis-krisis-2/data/output/hasil_gabungan.xlsx

# %%
import os

os.makedirs('src', exist_ok=True)
os.makedirs('data/kamus', exist_ok=True)

with open('run_pipeline.py', 'w') as f:
    f.write('''# Tulis atau tempel isi kode run_pipeline.py Anda di sini
print("Pipeline siap dijalankan!")
''')

print("Folder src dan file run_pipeline.py berhasil dibuat!")
# Out:
# Folder src dan file run_pipeline.py berhasil dibuat!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
